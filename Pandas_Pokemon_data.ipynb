# %% [markdown]
# # Loading Data into Pandas

# %%
import pandas as pd

poke = pd.read_csv('pokemon.csv')
#poke = pd.read_excel('pokemon.xlsx')
#poke = pd.read_csv('pokemon.txt', delimiter='\t')   #tab seperated file   \t can be 'xxx'

# %%
#print(poke)

# %%
poke.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
poke.tail(3)
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# # Reading Data in Pandas

# %%
# Read Headers
print(poke.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# Read each Column
print(poke['Name'][0:5])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
#print(poke.Name)

# %%
#print(poke[['Name', 'HP', 'Legendary']])

# %%
# Read each Row
print(poke.iloc[0:4])
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False

# %%
# Read specific location (R,C)
print(poke.iloc[2,1])
# Out:
# Venusaur

# %%
#for index, row in poke.iterrows():
#    print(index, row['Name'])

# %%
#poke.loc[poke['Type 1'] == 'Water']

# %% [markdown]
# # Sorting/Describing Data

# %%
poke.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
#poke.sort_values('Attack', ascending = False)

# %%
#poke.sort_values(['Type 1', 'HP'], ascending = [1,0])

# %% [markdown]
# # Making changes to the data

# %%
poke.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
poke = poke.drop(columns = 'Total')

# %%
poke.head(1)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary
# 0           1      False

# %%
#poke['Total'] = poke['HP'] + poke['Attack'] + poke['Defense'] + poke['Sp. Atk'] + poke['Sp. Def'] + poke['Speed']
poke.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total 2  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison      318  45      49       49
# 1  2                Ivysaur  Grass  Poison      405  60      62       63
# 2  3               Venusaur  Grass  Poison      525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison      625  80     100      123
# 4  4             Charmander   Fire     NaN      309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
45+49+49+65+65+45
# Out:
# 318

# %%
# Add a columns
poke['Total'] = poke.iloc[:,4:10].sum(axis = 1) #axis =1(horizontally), axis = 0(Vertically)

# %%
poke.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary  Total
# 0           1      False    318
# 1           1      False    405
# 2           1      False    525

# %%
# Switching total to the left side
cols = list(poke.columns)
poke = poke[cols[0:4] + [cols[-1]] + cols[4:12]]

poke.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %% [markdown]
# # Saving our Data

# %%
poke.to_csv('modified.csv', index = False)
# poke.to_excel('modefied.xlsx', index = False)
# poke.to_csv('modified.txt', index = False, sep='\t')

# %% [markdown]
# # Filering Data

# %%
#poke.loc[poke['Legendary'] == True]

# %%
poke.loc[(poke['Type 1'] == 'Fire') & (poke['Legendary'] == True)]  #& and sign, | or sign
# Out:
#        #       Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 158  146    Moltres   Fire  Flying    580   90     100       90      125
# 263  244      Entei   Fire     NaN    580  115     115       85       90
# 270  250      Ho-oh   Fire  Flying    680  106     130       90      110
# 542  485    Heatran   Fire   Steel    600   91      90      106      130
# 799  721  Volcanion   Fire   Water    600   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 158       85     90           1       True
# 263       75    100           2       True
# 270      154     90           2       True
# 542      106     77           4       True
# 799       90     70           6       True

# %%
legendary_poke = poke.loc[poke['Legendary'] == True]

# %%
legendary_poke.head()
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# 157       85      125       90    100           1       True
# 158       90      125       85     90           1       True
# 162       90      154       90    130           1       True
# 163      100      154      100    130           1       True

# %%
#legendary_poke = legendary_poke.sort_values('Total', ascending= False)
#legendary_poke

# %%
legendary_poke = legendary_poke.reset_index(drop = True)    #with new index
legendary_poke

legendary_poke.to_csv('legendary_poke.csv')

# %%
# All Mega pokemon
#poke.loc[poke['Name'].str.contains('Mega')]

# %%
#Removing all Mega pokemon with ~
#poke.loc[~poke['Name'].str.contains('Mega')]

# %%
import re   #Regex or Regular Expression

#poke.loc[poke['Type 1'].str.contains('Fire|Grass', regex = True)]

#poke.loc[poke['Type 1'].str.contains('fire|grass', flags = re.I, regex = True)]   #Ignore case

# %%
#poke.loc[poke['Name'].str.contains('^pi[a-z]*', flags = re.I, regex = True)]

# %% [markdown]
# # Conditinal Changes

# %%
poke.loc[poke['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'
poke.head(10)
# Out:
#    #                       Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur   Grass  Poison    318  45      49       49
# 1  2                    Ivysaur   Grass  Poison    405  60      62       63
# 2  3                   Venusaur   Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4  4                 Charmander  Flamer     NaN    309  39      52       43
# 5  5                 Charmeleon  Flamer     NaN    405  58      64       58
# 6  6                  Charizard  Flamer  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X  Flamer  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y  Flamer  Flying    634  78     104       78
# 9  7                   Squirtle   Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
poke.loc[poke['Type 1'] == 'Fire', 'Type 1'] = 'Fire'

# %%
#poke.loc[poke['Total'] > 500, ['Generation', 'Legendary']] = 'TEST VALUE'
#poke

# %%
poke = pd.read_csv('modified.csv')

# %%
poke.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# # Aggregate Statistics (Groupby)

# %%
poke.groupby(['Type 1']).mean()
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# ...

# %%
poke.groupby(['Type 1']).mean().sort_values('Total', ascending = False)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Steel     442.851852  487.703704  65.222222   92.703704  126.370370
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Psychic   380.807018  475.947368  70.631579   71.456140   67.684211
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Rock      392.727273  453.750000  65.363636   92.863636  100.795455
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# ...

# %%
poke.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug        69    69      52     69   69      69       69       69       69
# Dark       31    31      21     31   31      31       31       31       31
# Dragon     32    32      21     32   32      32       32       32       32
# Electric   44    44      17     44   44      44       44       44       44
# Fairy      17    17       2     17   17      17       17       17       17
# Fighting   27    27       7     27   27      27       27       27       27
# Fire       52    52      24     52   52      52       52       52       52
# Flying      4     4       2      4    4       4        4        4        4
# Ghost      32    32      22     32   32      32       32       32       32
# Grass      70    70      37     70   70      70       70       70       70
# Ground     32    32      19     32   32      32       32       32       32
# ...

# %%
poke['count'] =1
poke.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
#poke.groupby(['Type 1', 'Type 2']).count()['count']

# %% [markdown]
# # Working with large amounts of data

# %%
#for poke in pd.read_csv('modified.csv', chunksize = 5):
#    print("Chunk DF")
#    print(poke)

# %%
new_df = pd.DataFrame(columns = poke.columns)

for poke in pd.read_csv('modified.csv', chunksize = 20):
    results = poke.groupby(['Type 1']).count()
    
    ne_df = pd.concat([new_df, results])
# Out:
# /Users/tenzintsundue/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
